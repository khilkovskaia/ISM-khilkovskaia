# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
d = pd.read_csv('gradedata.csv')
hours = d['hours']
grade = d['grade']
plt.scatter(hours, grade, color='g')
plt.xlabel('Hours')
plt.ylabel('Grades')
plt.show()
